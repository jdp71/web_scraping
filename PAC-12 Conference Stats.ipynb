# %% [markdown]
# For this project, I am going to scrape the www.cfbstats.com site for the PAC-12 college football conference statistics.  I will perform two separate scrapes and then combine the two into a single DataFrame.
#
# First I need to load the necessary modules.

# %%
import requests
from bs4 import BeautifulSoup
import lxml.html as lh
import pandas as pd

# %% [markdown]
# I am going to start with the conference statistics.

# %% [markdown]
# # Conference Stats

# %%
url='http://www.cfbstats.com/2019/leader/905/team/offense/split01/category09/sort01.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=10:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Name"
# 3:"G"
# 4:"TD"
# 5:"FG"
# 6:"1XP"
# 7:"2XP"
# 8:"Safety"
# 9:"Points"
# 10:"Points/G"

# %% [markdown]
# This code chunk pulled out the column headers.  I knew there were 10 columns so that I why the line of code `if len(T)!=10` is set at that value.  You will see later on that I have to change that value for the individual team data scrapes.
#
# Having done this, we are now ready to create the DataFrame with the scraped table values.

# %%
dict_conf={title:column for (title,column) in col}
df_conf=pd.DataFrame(dict_conf)
df_conf
# Out:
#                     Name  G  TD  FG  1XP  2XP  Safety  Points Points/G
# 0    1  Washington State  8  42  13   41    1       0     334     41.8
# 1    2            Oregon  8  39   5   37    1       0     288     36.0
# 2    3        Washington  8  34  15   33    1       1     286     35.8
# 3    4              Utah  8  35   7   34    0       0     265     33.1
# 4    5           Arizona  8  34   6   32    1       1     258     32.3
# 5    6               USC  8  32   8   32    0       1     250     31.3
# 6    7      Oregon State  7  30   2   27    0       0     213     30.4
# 7    8              UCLA  8  31   5   30    1       0     233     29.1
# 8    9          Colorado  8  26  12   25    0       0     217     27.1
# 9   10     Arizona State  8  21  13   20    1       0     187     23.4
# 10  11          Stanford  8  20  14   19    0       0     181     22.6
# 11  12        California  8  16   9   16    0       0     139     17.4

# %% [markdown]
# That worked perfectly.  We do, however, have a redundant column that I will go ahead and drop.

# %%
df_conf = df_conf.drop([df_conf.columns[0]],  axis='columns')
df_conf
# Out:
#                 Name  G  TD  FG  1XP  2XP  Safety  Points Points/G
# 0   Washington State  8  42  13   41    1       0     334     41.8
# 1             Oregon  8  39   5   37    1       0     288     36.0
# 2         Washington  8  34  15   33    1       1     286     35.8
# 3               Utah  8  35   7   34    0       0     265     33.1
# 4            Arizona  8  34   6   32    1       1     258     32.3
# 5                USC  8  32   8   32    0       1     250     31.3
# 6       Oregon State  7  30   2   27    0       0     213     30.4
# 7               UCLA  8  31   5   30    1       0     233     29.1
# 8           Colorado  8  26  12   25    0       0     217     27.1
# 9      Arizona State  8  21  13   20    1       0     187     23.4
# 10          Stanford  8  20  14   19    0       0     181     22.6
# 11        California  8  16   9   16    0       0     139     17.4

# %% [markdown]
# Okay, our first scrape was successful and we have our first DataFrame of the conference statistics.  Because there are only nine variables, I will do another scrape for each team within the conference.

# %% [markdown]
# # Team Stats

# %% [markdown]
# I tried using a looping function that would scrape for each team all at once, but I couldn't ever get it to work.  I spent hours trying to figure it out but ultimately had to just repeat the process separately for each team.  Because of this, I will not provide explanations for each team since they are all the same.  I will just provide them for the first team, Utah Utes.

# %% [markdown]
# **Utah Utes**

# %%
url='http://www.cfbstats.com/2019/team/732/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Utah"
# 3:"Opponents"

# %% [markdown]
# As I mentioned earlier, I knew that I would have to change the `if len(T)!=3` section to the correct value for this table.
#
# One interesting thing about this particular scrape is that the data are set up differently than what we are used to.  The data are transposed, meaning that the variables that are normally columns are set up as rows (see image below).  This isn't a big deal because we can still scrape the data and then perform a transpose function to orient things correctly.

# %%
from IPython.display import Image
img = 'screenshot1.png'
Image(url=img)
# Out:
# <img src="screenshot1.png"/>

# %%
dict_utah={title:column for (title,column) in col}
df_utah=pd.DataFrame(dict_utah)
df_utah
# Out:
#                                                                      Utah  \
# 0                               Scoring:  Points/Game                33.1
# 1                            Scoring:  Games - Points             8 - 265
# 2                                 First Downs:  Total                 185
# 3        First Downs:  Rushing - Passing - By Penalty        92 - 75 - 18
# 4                           Rushing:  Yards / Attempt                5.07
# 5                     Rushing:  Attempts - Yards - TD     346 - 1755 - 21
# 6                                    Passing:  Rating              175.61
# 7                                     Passing:  Yards                1864
# 8   Passing:  Attempts - Completions - Interceptio...  185 - 134 - 1 - 11
# 9                        Total Offense:  Yards / Play                6.82
# 10                      Total Offense:  Plays - Yards          531 - 3619
# 11                      Punt Returns:  Yards / Return                6.00
# 12                Punt Returns:  Returns - Yards - TD         15 - 90 - 0
# 13                   Kickoff Returns:  Yards / Return               14.17
# 14             Kickoff Returns:  Returns - Yards - TD          6 - 85 - 0
# 15                             Punting:  Yards / Punt               39.36
# 16                            Punting:  Punts - Yards            22 - 866
# 17               Interceptions:  Returns - Yards - TD         9 - 226 - 3
# 18                            Fumbles:  Number - Lost               9 - 6
# 19                         Penalties:  Number - Yards            60 - 531
# 20                          Time of Possession / Game            35:16.38
# 21                 3rd Down Conversions: Conversion %              45.83%
# 22      3rd Down Conversions:  Attempts - Conversions             96 - 44
# 23                 4th Down Conversions: Conversion %              64.29%
# 24      4th Down Conversions:  Attempts - Conversions              14 - 9
# 25                               Red Zone:  Success %              80.56%
# 26                       Red Zone:  Attempts - Scores             36 - 29
# 27                            Field Goals:  Success %               63.6%
# 28                      Field Goals:  Attempts - Made              11 - 7
# 29                            PAT Kicking:  Success %               97.1%
# 30                      PAT Kicking:  Attempts - Made             35 - 34
# 31                    2-Point Conversions:  Success %                   -
# 32              2-Point Conversions:  Attempts - Made               0 - 0
#
#             Opponents
# 0                10.3
# 1              8 - 82
# 2                 101
# 3        29 - 60 - 12
# 4                2.45
# 5       184 - 451 - 3
# 6              103.66
# 7                1397
# 8   250 - 140 - 9 - 6
# 9                4.26
# 10         434 - 1848
# 11               5.00
# 12         3 - 15 - 0
# 13              21.33
# 14       18 - 384 - 0
# 15              43.13
# 16          48 - 2070
# 17         1 - 21 - 0
# 18              8 - 3
# 19           52 - 464
# 20           24:43.63
# 21             26.32%
# 22            95 - 25
# 23             44.44%
# 24              9 - 4
# 25                75%
# 26             12 - 9
# 27              66.7%
# 28              9 - 6
# 29               100%
# 30              8 - 8
# 31                 0%
# 32              1 - 0

# %% [markdown]
# Our scrape was successful.
#
# I am not interested in the "Opponent" column, so I will drop that.  I will also perform a transform to the DataFrame to make the rows into columns.
#
# Also, when I did the transpose, it made my header column appear as the first row of data.  Therefore, I need to delete that row and turn it into a header.

# %%
df_utah = df_utah.drop(columns=['Opponents']).T
header = df_utah.iloc[0]
df_utah = df_utah[1:]
df_utah = df_utah.rename(columns = header)
df_utah
# Out:
#      Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# Utah                  33.1                  8 - 265                 185
#
#      First Downs:  Rushing - Passing - By Penalty Rushing:  Yards / Attempt  \
# Utah                                 92 - 75 - 18                      5.07
#
#      Rushing:  Attempts - Yards - TD Passing:  Rating Passing:  Yards  \
# Utah                 346 - 1755 - 21           175.61            1864
#
#      Passing:  Attempts - Completions - Interceptions - TD  \
# Utah                                 185 - 134 - 1 - 11
#
#      Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# Utah                         6.82  ...                             64.29%
#
#      4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# Utah                                        14 - 9               80.56%
#
#      Red Zone:  Attempts - Scores Field Goals:  Success %  \
# Utah                      36 - 29                   63.6%
#
#      Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# Utah                        11 - 7                   97.1%
#
#      PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# Utah                       35 - 34                               -
#
#      2-Point Conversions:  Attempts - Made
# Utah                                 0 - 0
#
# [1 rows x 33 columns]

# %% [markdown]
# Okay, after a successful scrape and many data transformation/clean-up steps, we have generated another DataFrame for an individual PAC-12 team, the Utah Utes.  Here are the transformation/clean-up steps we performed: dropped an unnecessary column, transposed the data from rows to columns, and assigned an appropriate column header.
#
# This process will be repeated for each individual PAC-12 team.

# %% [markdown]
# **Washington State Cougars**

# %%
url='http://www.cfbstats.com/2019/team/754/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Washington State"
# 3:"Opponents"

# %%
dict_wash_st={title:column for (title,column) in col}
df_wash_st=pd.DataFrame(dict_wash_st)
df_wash_st
# Out:
#                                                          Washington State  \
# 0                               Scoring:  Points/Game                41.8
# 1                            Scoring:  Games - Points             8 - 334
# 2                                 First Downs:  Total                 202
# 3        First Downs:  Rushing - Passing - By Penalty       36 - 154 - 12
# 4                           Rushing:  Yards / Attempt                5.10
# 5                     Rushing:  Attempts - Yards - TD       134 - 684 - 8
# 6                                    Passing:  Rating              162.07
# 7                                     Passing:  Yards                3491
# 8   Passing:  Attempts - Completions - Interceptio...  418 - 290 - 9 - 34
# 9                        Total Offense:  Yards / Play                7.56
# 10                      Total Offense:  Plays - Yards          552 - 4175
# 11                      Punt Returns:  Yards / Return               13.60
# 12                Punt Returns:  Returns - Yards - TD          5 - 68 - 0
# 13                   Kickoff Returns:  Yards / Return               20.78
# 14             Kickoff Returns:  Returns - Yards - TD        23 - 478 - 0
# 15                             Punting:  Yards / Punt               44.00
# 16                            Punting:  Punts - Yards            22 - 968
# 17               Interceptions:  Returns - Yards - TD          6 - 84 - 0
# 18                            Fumbles:  Number - Lost               5 - 4
# 19                         Penalties:  Number - Yards            59 - 535
# 20                          Time of Possession / Game            29:02.63
# 21                 3rd Down Conversions: Conversion %              38.82%
# 22      3rd Down Conversions:  Attempts - Conversions             85 - 33
# 23                 4th Down Conversions: Conversion %              72.73%
# 24      4th Down Conversions:  Attempts - Conversions              11 - 8
# 25                               Red Zone:  Success %              92.68%
# 26                       Red Zone:  Attempts - Scores             41 - 38
# 27                            Field Goals:  Success %                100%
# 28                      Field Goals:  Attempts - Made             13 - 13
# 29                            PAT Kicking:  Success %                100%
# 30                      PAT Kicking:  Attempts - Made             41 - 41
# 31                    2-Point Conversions:  Success %                100%
# 32              2-Point Conversions:  Attempts - Made               1 - 1
#
#              Opponents
# 0                 29.8
# 1              8 - 238
# 2                  186
# 3         82 - 87 - 17
# 4                 4.97
# 5      311 - 1547 - 16
# 6               142.77
# 7                 2055
# 8   250 - 160 - 6 - 11
# 9                 6.42
# 10          561 - 3602
# 11               22.75
# 12          4 - 91 - 1
# 13               21.35
# 14        17 - 363 - 1
# 15               40.00
# 16           33 - 1320
# 17          9 - 62 - 1
# 18              13 - 7
# 19            62 - 542
# 20            30:57.38
# 21              43.93%
# 22            107 - 47
# 23              63.64%
# 24              11 - 7
# 25                 80%
# 26             30 - 24
# 27               64.3%
# 28              14 - 9
# 29               96.4%
# 30             28 - 27
# 31                100%
# 32               2 - 2

# %%
df_wash_st = df_wash_st.drop(columns=['Opponents']).T
header = df_wash_st.iloc[0]
df_wash_st = df_wash_st[1:]
df_wash_st = df_wash_st.rename(columns = header)
df_wash_st
# Out:
#                  Scoring:  Points/Game Scoring:  Games - Points  \
# Washington State                  41.8                  8 - 334
#
#                  First Downs:  Total  \
# Washington State                 202
#
#                  First Downs:  Rushing - Passing - By Penalty  \
# Washington State                                36 - 154 - 12
#
#                  Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Washington State                      5.10                   134 - 684 - 8
#
#                  Passing:  Rating Passing:  Yards  \
# Washington State           162.07            3491
#
#                  Passing:  Attempts - Completions - Interceptions - TD  \
# Washington State                                 418 - 290 - 9 - 34
#
#                  Total Offense:  Yards / Play  ...  \
# Washington State                         7.56  ...
#
#                  4th Down Conversions: Conversion %  \
# Washington State                             72.73%
#
#                  4th Down Conversions:  Attempts - Conversions  \
# Washington State                                        11 - 8
#
#                  Red Zone:  Success % Red Zone:  Attempts - Scores  \
# Washington State               92.68%                      41 - 38
#
#                  Field Goals:  Success % Field Goals:  Attempts - Made  \
# Washington State                    100%                       13 - 13
#
#                  PAT Kicking:  Success % PAT Kicking:  Attempts - Made  \
# Washington State                    100%                       41 - 41
#
#                  2-Point Conversions:  Success %  \
# Washington State                            100%
#
#                  2-Point Conversions:  Attempts - Made
# Washington State                                 1 - 1
#
# [1 rows x 33 columns]

# %% [markdown]
# **Oregon Ducks**

# %%
url='http://www.cfbstats.com/2019/team/529/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Oregon"
# 3:"Opponents"

# %%
dict_ore={title:column for (title,column) in col}
df_ore=pd.DataFrame(dict_ore)
df_ore
# Out:
#                                                                    Oregon  \
# 0                               Scoring:  Points/Game                36.0
# 1                            Scoring:  Games - Points             8 - 288
# 2                                 First Downs:  Total                 193
# 3        First Downs:  Rushing - Passing - By Penalty       72 - 107 - 14
# 4                           Rushing:  Yards / Attempt                5.05
# 5                     Rushing:  Attempts - Yards - TD     301 - 1521 - 14
# 6                                    Passing:  Rating              162.43
# 7                                     Passing:  Yards                2207
# 8   Passing:  Attempts - Completions - Interceptio...  276 - 189 - 1 - 23
# 9                        Total Offense:  Yards / Play                6.46
# 10                      Total Offense:  Plays - Yards          577 - 3728
# 11                      Punt Returns:  Yards / Return               18.45
# 12                Punt Returns:  Returns - Yards - TD        11 - 203 - 0
# 13                   Kickoff Returns:  Yards / Return               21.82
# 14             Kickoff Returns:  Returns - Yards - TD        17 - 371 - 0
# 15                             Punting:  Yards / Punt               43.45
# 16                            Punting:  Punts - Yards           33 - 1434
# 17               Interceptions:  Returns - Yards - TD        14 - 166 - 1
# 18                            Fumbles:  Number - Lost               7 - 4
# 19                         Penalties:  Number - Yards            47 - 476
# 20                          Time of Possession / Game            28:58.38
# 21                 3rd Down Conversions: Conversion %              43.81%
# 22      3rd Down Conversions:  Attempts - Conversions            105 - 46
# 23                 4th Down Conversions: Conversion %                 50%
# 24      4th Down Conversions:  Attempts - Conversions              18 - 9
# 25                               Red Zone:  Success %              80.49%
# 26                       Red Zone:  Attempts - Scores             41 - 33
# 27                            Field Goals:  Success %               62.5%
# 28                      Field Goals:  Attempts - Made               8 - 5
# 29                            PAT Kicking:  Success %               97.4%
# 30                      PAT Kicking:  Attempts - Made             38 - 37
# 31                    2-Point Conversions:  Success %                100%
# 32              2-Point Conversions:  Attempts - Made               1 - 1
#
#              Opponents
# 0                 14.8
# 1              8 - 118
# 2                  140
# 3         48 - 77 - 15
# 4                 3.16
# 5        256 - 810 - 3
# 6               107.05
# 7                 1656
# 8   281 - 160 - 14 - 9
# 9                 4.59
# 10          537 - 2466
# 11                7.67
# 12         12 - 92 - 0
# 13               22.11
# 14        27 - 597 - 0
# 15               42.45
# 16           47 - 1995
# 17          1 - 31 - 0
# 18               8 - 2
# 19            65 - 548
# 20            31:01.63
# 21              32.26%
# 22            124 - 40
# 23                 50%
# 24              16 - 8
# 25              70.83%
# 26             24 - 17
# 27               68.8%
# 28             16 - 11
# 29                100%
# 30             11 - 11
# 31                100%
# 32               1 - 1

# %%
df_ore = df_ore.drop(columns=['Opponents']).T
header = df_ore.iloc[0]
df_ore = df_ore[1:]
df_ore = df_ore.rename(columns = header)
df_ore
# Out:
#        Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# Oregon                  36.0                  8 - 288                 193
#
#        First Downs:  Rushing - Passing - By Penalty Rushing:  Yards / Attempt  \
# Oregon                                72 - 107 - 14                      5.05
#
#        Rushing:  Attempts - Yards - TD Passing:  Rating Passing:  Yards  \
# Oregon                 301 - 1521 - 14           162.43            2207
#
#        Passing:  Attempts - Completions - Interceptions - TD  \
# Oregon                                 276 - 189 - 1 - 23
#
#        Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# Oregon                         6.46  ...                                50%
#
#        4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# Oregon                                        18 - 9               80.49%
#
#        Red Zone:  Attempts - Scores Field Goals:  Success %  \
# Oregon                      41 - 33                   62.5%
#
#        Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# Oregon                         8 - 5                   97.4%
#
#        PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# Oregon                       38 - 37                            100%
#
#        2-Point Conversions:  Attempts - Made
# Oregon                                 1 - 1
#
# [1 rows x 33 columns]

# %% [markdown]
# **Washington Huskies**

# %%
url='http://www.cfbstats.com/2019/team/756/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Washington"
# 3:"Opponents"

# %%
dict_wash={title:column for (title,column) in col}
df_wash=pd.DataFrame(dict_wash)
df_wash
# Out:
#                                                                Washington  \
# 0                               Scoring:  Points/Game                35.8
# 1                            Scoring:  Games - Points             8 - 286
# 2                                 First Downs:  Total                 168
# 3        First Downs:  Rushing - Passing - By Penalty        75 - 83 - 10
# 4                           Rushing:  Yards / Attempt                4.66
# 5                     Rushing:  Attempts - Yards - TD     295 - 1376 - 15
# 6                                    Passing:  Rating              158.39
# 7                                     Passing:  Yards                2000
# 8   Passing:  Attempts - Completions - Interceptio...  236 - 159 - 3 - 16
# 9                        Total Offense:  Yards / Play                6.36
# 10                      Total Offense:  Plays - Yards          531 - 3376
# 11                      Punt Returns:  Yards / Return               10.63
# 12                Punt Returns:  Returns - Yards - TD        16 - 170 - 1
# 13                   Kickoff Returns:  Yards / Return               21.36
# 14             Kickoff Returns:  Returns - Yards - TD        11 - 235 - 0
# 15                             Punting:  Yards / Punt               43.68
# 16                            Punting:  Punts - Yards           28 - 1223
# 17               Interceptions:  Returns - Yards - TD          8 - 43 - 0
# 18                            Fumbles:  Number - Lost              10 - 4
# 19                         Penalties:  Number - Yards            50 - 416
# 20                          Time of Possession / Game            30:09.25
# 21                 3rd Down Conversions: Conversion %              35.35%
# 22      3rd Down Conversions:  Attempts - Conversions             99 - 35
# 23                 4th Down Conversions: Conversion %               62.5%
# 24      4th Down Conversions:  Attempts - Conversions             16 - 10
# 25                               Red Zone:  Success %              91.43%
# 26                       Red Zone:  Attempts - Scores             35 - 32
# 27                            Field Goals:  Success %                100%
# 28                      Field Goals:  Attempts - Made             15 - 15
# 29                            PAT Kicking:  Success %                100%
# 30                      PAT Kicking:  Attempts - Made             33 - 33
# 31                    2-Point Conversions:  Success %                100%
# 32              2-Point Conversions:  Attempts - Made               1 - 1
#
#              Opponents
# 0                 21.5
# 1              8 - 172
# 2                  168
# 3         68 - 85 - 15
# 4                 4.19
# 5      282 - 1181 - 11
# 6               119.86
# 7                 1798
# 8   277 - 164 - 8 - 10
# 9                 5.33
# 10          559 - 2979
# 11                1.17
# 12           6 - 7 - 0
# 13               20.53
# 14        17 - 349 - 0
# 15               36.53
# 16           40 - 1461
# 17          3 - 33 - 0
# 18               9 - 5
# 19            48 - 401
# 20            29:50.75
# 21              36.28%
# 22            113 - 41
# 23              73.33%
# 24             15 - 11
# 25              84.62%
# 26             26 - 22
# 27                 75%
# 28              12 - 9
# 29                 95%
# 30             20 - 19
# 31                  0%
# 32               1 - 0

# %%
df_wash = df_wash.drop(columns=['Opponents']).T
header = df_wash.iloc[0]
df_wash = df_wash[1:]
df_wash = df_wash.rename(columns = header)
df_wash
# Out:
#            Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# Washington                  35.8                  8 - 286                 168
#
#            First Downs:  Rushing - Passing - By Penalty  \
# Washington                                 75 - 83 - 10
#
#            Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Washington                      4.66                 295 - 1376 - 15
#
#            Passing:  Rating Passing:  Yards  \
# Washington           158.39            2000
#
#            Passing:  Attempts - Completions - Interceptions - TD  \
# Washington                                 236 - 159 - 3 - 16
#
#            Total Offense:  Yards / Play  ...  \
# Washington                         6.36  ...
#
#            4th Down Conversions: Conversion %  \
# Washington                              62.5%
#
#            4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# Washington                                       16 - 10               91.43%
#
#            Red Zone:  Attempts - Scores Field Goals:  Success %  \
# Washington                      35 - 32                    100%
#
#            Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# Washington                       15 - 15                    100%
#
#            PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# Washington                       33 - 33                            100%
#
#            2-Point Conversions:  Attempts - Made
# Washington                                 1 - 1
#
# [1 rows x 33 columns]

# %% [markdown]
# **Arizona Wildcats**

# %%
url='http://www.cfbstats.com/2019/team/29/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Arizona"
# 3:"Opponents"

# %%
dict_arz={title:column for (title,column) in col}
df_arz=pd.DataFrame(dict_arz)
df_arz
# Out:
#                                                                   Arizona  \
# 0                               Scoring:  Points/Game                32.3
# 1                            Scoring:  Games - Points             8 - 258
# 2                                 First Downs:  Total                 189
# 3        First Downs:  Rushing - Passing - By Penalty        82 - 101 - 6
# 4                           Rushing:  Yards / Attempt                5.24
# 5                     Rushing:  Attempts - Yards - TD     309 - 1620 - 15
# 6                                    Passing:  Rating              147.45
# 7                                     Passing:  Yards                2316
# 8   Passing:  Attempts - Completions - Interceptio...  285 - 181 - 9 - 19
# 9                        Total Offense:  Yards / Play                6.63
# 10                      Total Offense:  Plays - Yards          594 - 3936
# 11                      Punt Returns:  Yards / Return                5.50
# 12                Punt Returns:  Returns - Yards - TD         10 - 55 - 0
# 13                   Kickoff Returns:  Yards / Return               20.55
# 14             Kickoff Returns:  Returns - Yards - TD        20 - 411 - 0
# 15                             Punting:  Yards / Punt               38.63
# 16                            Punting:  Punts - Yards           40 - 1545
# 17               Interceptions:  Returns - Yards - TD          9 - 84 - 0
# 18                            Fumbles:  Number - Lost               9 - 6
# 19                         Penalties:  Number - Yards            51 - 417
# 20                          Time of Possession / Game            28:05.38
# 21                 3rd Down Conversions: Conversion %               45.9%
# 22      3rd Down Conversions:  Attempts - Conversions            122 - 56
# 23                 4th Down Conversions: Conversion %              81.82%
# 24      4th Down Conversions:  Attempts - Conversions              11 - 9
# 25                               Red Zone:  Success %                 88%
# 26                       Red Zone:  Attempts - Scores             25 - 22
# 27                            Field Goals:  Success %                 60%
# 28                      Field Goals:  Attempts - Made              10 - 6
# 29                            PAT Kicking:  Success %                 97%
# 30                      PAT Kicking:  Attempts - Made             33 - 32
# 31                    2-Point Conversions:  Success %                100%
# 32              2-Point Conversions:  Attempts - Made               1 - 1
#
#              Opponents
# 0                 35.0
# 1              8 - 280
# 2                  190
# 3        68 - 109 - 13
# 4                 4.64
# 5      273 - 1266 - 15
# 6               138.37
# 7                 2493
# 8   333 - 210 - 9 - 18
# 9                 6.20
# 10          606 - 3759
# 11                5.53
# 12         15 - 83 - 0
# 13               22.20
# 14        10 - 222 - 0
# 15               44.47
# 16           34 - 1512
# 17          9 - 70 - 0
# 18               5 - 4
# 19            51 - 441
# 20            31:54.63
# 21              43.97%
# 22            116 - 51
# 23              42.86%
# 24              14 - 6
# 25              94.44%
# 26             36 - 34
# 27               93.3%
# 28             15 - 14
# 29                100%
# 30             34 - 34
# 31                   -
# 32               0 - 0

# %%
df_arz = df_arz.drop(columns=['Opponents']).T
header = df_arz.iloc[0]
df_arz = df_arz[1:]
df_arz = df_arz.rename(columns = header)
df_arz
# Out:
#         Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# Arizona                  32.3                  8 - 258                 189
#
#         First Downs:  Rushing - Passing - By Penalty  \
# Arizona                                 82 - 101 - 6
#
#         Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Arizona                      5.24                 309 - 1620 - 15
#
#         Passing:  Rating Passing:  Yards  \
# Arizona           147.45            2316
#
#         Passing:  Attempts - Completions - Interceptions - TD  \
# Arizona                                 285 - 181 - 9 - 19
#
#         Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# Arizona                         6.63  ...                             81.82%
#
#         4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# Arizona                                        11 - 9                  88%
#
#         Red Zone:  Attempts - Scores Field Goals:  Success %  \
# Arizona                      25 - 22                     60%
#
#         Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# Arizona                        10 - 6                     97%
#
#         PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# Arizona                       33 - 32                            100%
#
#         2-Point Conversions:  Attempts - Made
# Arizona                                 1 - 1
#
# [1 rows x 33 columns]

# %% [markdown]
# **USC Trojans**

# %%
url='http://www.cfbstats.com/2019/team/657/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"USC"
# 3:"Opponents"

# %%
dict_usc={title:column for (title,column) in col}
df_usc=pd.DataFrame(dict_usc)
df_usc
# Out:
#                                                                        USC  \
# 0                               Scoring:  Points/Game                 31.3
# 1                            Scoring:  Games - Points              8 - 250
# 2                                 First Downs:  Total                  175
# 3        First Downs:  Rushing - Passing - By Penalty         64 - 102 - 9
# 4                           Rushing:  Yards / Attempt                 4.48
# 5                     Rushing:  Attempts - Yards - TD      261 - 1170 - 13
# 6                                    Passing:  Rating               155.46
# 7                                     Passing:  Yards                 2369
# 8   Passing:  Attempts - Completions - Interceptio...  282 - 200 - 10 - 18
# 9                        Total Offense:  Yards / Play                 6.52
# 10                      Total Offense:  Plays - Yards           543 - 3539
# 11                      Punt Returns:  Yards / Return                 5.33
# 12                Punt Returns:  Returns - Yards - TD          12 - 64 - 0
# 13                   Kickoff Returns:  Yards / Return                22.26
# 14             Kickoff Returns:  Returns - Yards - TD         31 - 690 - 1
# 15                             Punting:  Yards / Punt                41.91
# 16                            Punting:  Punts - Yards            34 - 1425
# 17               Interceptions:  Returns - Yards - TD           3 - 11 - 0
# 18                            Fumbles:  Number - Lost               12 - 5
# 19                         Penalties:  Number - Yards             53 - 563
# 20                          Time of Possession / Game             28:03.50
# 21                 3rd Down Conversions: Conversion %               43.56%
# 22      3rd Down Conversions:  Attempts - Conversions             101 - 44
# 23                 4th Down Conversions: Conversion %               66.67%
# 24      4th Down Conversions:  Attempts - Conversions                6 - 4
# 25                               Red Zone:  Success %               77.42%
# 26                       Red Zone:  Attempts - Scores              31 - 24
# 27                            Field Goals:  Success %                88.9%
# 28                      Field Goals:  Attempts - Made                9 - 8
# 29                            PAT Kicking:  Success %                 100%
# 30                      PAT Kicking:  Attempts - Made              32 - 32
# 31                    2-Point Conversions:  Success %                    -
# 32              2-Point Conversions:  Attempts - Made                0 - 0
#
#              Opponents
# 0                 24.9
# 1              8 - 199
# 2                  181
# 3         83 - 82 - 16
# 4                 4.84
# 5      314 - 1521 - 10
# 6               128.90
# 7                 1914
# 8   277 - 166 - 3 - 11
# 9                 5.81
# 10          591 - 3435
# 11                5.57
# 12          7 - 39 - 0
# 13               23.57
# 14        23 - 542 - 0
# 15               42.18
# 16           34 - 1434
# 17         10 - 60 - 0
# 18               9 - 6
# 19            64 - 499
# 20            31:56.50
# 21              37.39%
# 22            115 - 43
# 23              46.15%
# 24              13 - 6
# 25              80.65%
# 26             31 - 25
# 27               73.9%
# 28             23 - 17
# 29                100%
# 30             20 - 20
# 31                100%
# 32               1 - 1

# %%
df_usc = df_usc.drop(columns=['Opponents']).T
header = df_usc.iloc[0]
df_usc = df_usc[1:]
df_usc = df_usc.rename(columns = header)
df_usc
# Out:
#     Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# USC                  31.3                  8 - 250                 175
#
#     First Downs:  Rushing - Passing - By Penalty Rushing:  Yards / Attempt  \
# USC                                 64 - 102 - 9                      4.48
#
#     Rushing:  Attempts - Yards - TD Passing:  Rating Passing:  Yards  \
# USC                 261 - 1170 - 13           155.46            2369
#
#     Passing:  Attempts - Completions - Interceptions - TD  \
# USC                                282 - 200 - 10 - 18
#
#     Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# USC                         6.52  ...                             66.67%
#
#     4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# USC                                         6 - 4               77.42%
#
#     Red Zone:  Attempts - Scores Field Goals:  Success %  \
# USC                      31 - 24                   88.9%
#
#     Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# USC                         9 - 8                    100%
#
#     PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# USC                       32 - 32                               -
#
#     2-Point Conversions:  Attempts - Made
# USC                                 0 - 0
#
# [1 rows x 33 columns]

# %% [markdown]
# **Oregon State Beavers**

# %%
url='http://www.cfbstats.com/2019/team/528/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Oregon State"
# 3:"Opponents"

# %%
dict_orst={title:column for (title,column) in col}
df_orst=pd.DataFrame(dict_orst)
df_orst
# Out:
#                                                              Oregon State  \
# 0                               Scoring:  Points/Game                30.4
# 1                            Scoring:  Games - Points             7 - 213
# 2                                 First Downs:  Total                 160
# 3        First Downs:  Rushing - Passing - By Penalty         69 - 82 - 9
# 4                           Rushing:  Yards / Attempt                4.88
# 5                     Rushing:  Attempts - Yards - TD     240 - 1170 - 12
# 6                                    Passing:  Rating              138.28
# 7                                     Passing:  Yards                1706
# 8   Passing:  Attempts - Completions - Interceptio...  250 - 147 - 2 - 18
# 9                        Total Offense:  Yards / Play                5.87
# 10                      Total Offense:  Plays - Yards          490 - 2876
# 11                      Punt Returns:  Yards / Return                4.67
# 12                Punt Returns:  Returns - Yards - TD          9 - 42 - 0
# 13                   Kickoff Returns:  Yards / Return               24.15
# 14             Kickoff Returns:  Returns - Yards - TD        20 - 483 - 0
# 15                             Punting:  Yards / Punt               43.81
# 16                            Punting:  Punts - Yards           31 - 1358
# 17               Interceptions:  Returns - Yards - TD          3 - 16 - 0
# 18                            Fumbles:  Number - Lost               4 - 0
# 19                         Penalties:  Number - Yards            49 - 423
# 20                          Time of Possession / Game            27:45.14
# 21                 3rd Down Conversions: Conversion %              46.88%
# 22      3rd Down Conversions:  Attempts - Conversions             96 - 45
# 23                 4th Down Conversions: Conversion %              71.43%
# 24      4th Down Conversions:  Attempts - Conversions             14 - 10
# 25                               Red Zone:  Success %              88.46%
# 26                       Red Zone:  Attempts - Scores             26 - 23
# 27                            Field Goals:  Success %               28.6%
# 28                      Field Goals:  Attempts - Made               7 - 2
# 29                            PAT Kicking:  Success %               96.4%
# 30                      PAT Kicking:  Attempts - Made             28 - 27
# 31                    2-Point Conversions:  Success %                  0%
# 32              2-Point Conversions:  Attempts - Made               2 - 0
#
#              Opponents
# 0                 31.6
# 1              7 - 221
# 2                  165
# 3         73 - 75 - 17
# 4                 4.48
# 5      299 - 1341 - 12
# 6               152.76
# 7                 1647
# 8   205 - 128 - 3 - 16
# 9                 5.93
# 10          504 - 2988
# 11                6.08
# 12         13 - 79 - 0
# 13               27.05
# 14        20 - 541 - 0
# 15               42.24
# 16            21 - 887
# 17          2 - 72 - 1
# 18               6 - 3
# 19            36 - 316
# 20            32:14.00
# 21                 48%
# 22            100 - 48
# 23              64.29%
# 24              14 - 9
# 25              78.57%
# 26             28 - 22
# 27               46.2%
# 28              13 - 6
# 29                100%
# 30             29 - 29
# 31                   -
# 32               0 - 0

# %%
df_orst = df_orst.drop(columns=['Opponents']).T
header = df_orst.iloc[0]
df_orst = df_orst[1:]
df_orst = df_orst.rename(columns = header)
df_orst
# Out:
#              Scoring:  Points/Game Scoring:  Games - Points  \
# Oregon State                  30.4                  7 - 213
#
#              First Downs:  Total First Downs:  Rushing - Passing - By Penalty  \
# Oregon State                 160                                  69 - 82 - 9
#
#              Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Oregon State                      4.88                 240 - 1170 - 12
#
#              Passing:  Rating Passing:  Yards  \
# Oregon State           138.28            1706
#
#              Passing:  Attempts - Completions - Interceptions - TD  \
# Oregon State                                 250 - 147 - 2 - 18
#
#              Total Offense:  Yards / Play  ...  \
# Oregon State                         5.87  ...
#
#              4th Down Conversions: Conversion %  \
# Oregon State                             71.43%
#
#              4th Down Conversions:  Attempts - Conversions  \
# Oregon State                                       14 - 10
#
#              Red Zone:  Success % Red Zone:  Attempts - Scores  \
# Oregon State               88.46%                      26 - 23
#
#              Field Goals:  Success % Field Goals:  Attempts - Made  \
# Oregon State                   28.6%                         7 - 2
#
#              PAT Kicking:  Success % PAT Kicking:  Attempts - Made  \
# Oregon State                   96.4%                       28 - 27
#
#              2-Point Conversions:  Success %  \
# Oregon State                              0%
#
#              2-Point Conversions:  Attempts - Made
# Oregon State                                 2 - 0
#
# [1 rows x 33 columns]

# %% [markdown]
# **UCLA Bruins**

# %%
url='http://www.cfbstats.com/2019/team/110/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"UCLA"
# 3:"Opponents"

# %%
dict_ucla={title:column for (title,column) in col}
df_ucla=pd.DataFrame(dict_ucla)
df_ucla
# Out:
#                                                                      UCLA  \
# 0                               Scoring:  Points/Game                29.1
# 1                            Scoring:  Games - Points             8 - 233
# 2                                 First Downs:  Total                 176
# 3        First Downs:  Rushing - Passing - By Penalty        77 - 83 - 16
# 4                           Rushing:  Yards / Attempt                4.02
# 5                     Rushing:  Attempts - Yards - TD     333 - 1337 - 13
# 6                                    Passing:  Rating              134.34
# 7                                     Passing:  Yards                1895
# 8   Passing:  Attempts - Completions - Interceptio...  265 - 158 - 7 - 16
# 9                        Total Offense:  Yards / Play                5.40
# 10                      Total Offense:  Plays - Yards          598 - 3232
# 11                      Punt Returns:  Yards / Return               22.50
# 12                Punt Returns:  Returns - Yards - TD         8 - 180 - 1
# 13                   Kickoff Returns:  Yards / Return               24.42
# 14             Kickoff Returns:  Returns - Yards - TD        12 - 293 - 1
# 15                             Punting:  Yards / Punt               41.44
# 16                            Punting:  Punts - Yards           32 - 1326
# 17               Interceptions:  Returns - Yards - TD          3 - 72 - 0
# 18                            Fumbles:  Number - Lost              13 - 7
# 19                         Penalties:  Number - Yards            56 - 439
# 20                          Time of Possession / Game            29:49.00
# 21                 3rd Down Conversions: Conversion %              42.86%
# 22      3rd Down Conversions:  Attempts - Conversions            119 - 51
# 23                 4th Down Conversions: Conversion %              42.86%
# 24      4th Down Conversions:  Attempts - Conversions              21 - 9
# 25                               Red Zone:  Success %              81.82%
# 26                       Red Zone:  Attempts - Scores             33 - 27
# 27                            Field Goals:  Success %               62.5%
# 28                      Field Goals:  Attempts - Made               8 - 5
# 29                            PAT Kicking:  Success %                100%
# 30                      PAT Kicking:  Attempts - Made             30 - 30
# 31                    2-Point Conversions:  Success %                100%
# 32              2-Point Conversions:  Attempts - Made               1 - 1
#
#              Opponents
# 0                 34.3
# 1              8 - 274
# 2                  169
# 3         53 - 107 - 9
# 4                 4.13
# 5      278 - 1147 - 10
# 6               168.87
# 7                 2454
# 8   272 - 180 - 3 - 24
# 9                 6.55
# 10          550 - 3601
# 11               13.80
# 12        10 - 138 - 1
# 13               21.57
# 14         7 - 151 - 0
# 15               43.16
# 16           32 - 1381
# 17          7 - 41 - 0
# 18               8 - 7
# 19            54 - 394
# 20            30:11.00
# 21              44.04%
# 22            109 - 48
# 23                 50%
# 24              12 - 6
# 25              84.38%
# 26             32 - 27
# 27               76.9%
# 28             13 - 10
# 29                 97%
# 30             33 - 32
# 31                 50%
# 32               2 - 1

# %%
df_ucla = df_ucla.drop(columns=['Opponents']).T
header = df_ucla.iloc[0]
df_ucla = df_ucla[1:]
df_ucla = df_ucla.rename(columns = header)
df_ucla
# Out:
#      Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# UCLA                  29.1                  8 - 233                 176
#
#      First Downs:  Rushing - Passing - By Penalty Rushing:  Yards / Attempt  \
# UCLA                                 77 - 83 - 16                      4.02
#
#      Rushing:  Attempts - Yards - TD Passing:  Rating Passing:  Yards  \
# UCLA                 333 - 1337 - 13           134.34            1895
#
#      Passing:  Attempts - Completions - Interceptions - TD  \
# UCLA                                 265 - 158 - 7 - 16
#
#      Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# UCLA                         5.40  ...                             42.86%
#
#      4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# UCLA                                        21 - 9               81.82%
#
#      Red Zone:  Attempts - Scores Field Goals:  Success %  \
# UCLA                      33 - 27                   62.5%
#
#      Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# UCLA                         8 - 5                    100%
#
#      PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# UCLA                       30 - 30                            100%
#
#      2-Point Conversions:  Attempts - Made
# UCLA                                 1 - 1
#
# [1 rows x 33 columns]

# %% [markdown]
# **Colorado Buffaloes**

# %%
url='http://www.cfbstats.com/2019/team/157/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Colorado"
# 3:"Opponents"

# %%
dict_col={title:column for (title,column) in col}
df_col=pd.DataFrame(dict_col)
df_col
# Out:
#                                                                  Colorado  \
# 0                               Scoring:  Points/Game                27.1
# 1                            Scoring:  Games - Points             8 - 217
# 2                                 First Downs:  Total                 175
# 3        First Downs:  Rushing - Passing - By Penalty        73 - 90 - 12
# 4                           Rushing:  Yards / Attempt                4.31
# 5                     Rushing:  Attempts - Yards - TD     296 - 1277 - 11
# 6                                    Passing:  Rating              133.69
# 7                                     Passing:  Yards                2097
# 8   Passing:  Attempts - Completions - Interceptio...  289 - 182 - 9 - 14
# 9                        Total Offense:  Yards / Play                5.77
# 10                      Total Offense:  Plays - Yards          585 - 3374
# 11                      Punt Returns:  Yards / Return                6.13
# 12                Punt Returns:  Returns - Yards - TD          8 - 49 - 0
# 13                   Kickoff Returns:  Yards / Return               23.41
# 14             Kickoff Returns:  Returns - Yards - TD        17 - 398 - 0
# 15                             Punting:  Yards / Punt               44.55
# 16                            Punting:  Punts - Yards           38 - 1693
# 17               Interceptions:  Returns - Yards - TD          8 - 11 - 0
# 18                            Fumbles:  Number - Lost               6 - 2
# 19                         Penalties:  Number - Yards            64 - 536
# 20                          Time of Possession / Game            31:24.38
# 21                 3rd Down Conversions: Conversion %                 44%
# 22      3rd Down Conversions:  Attempts - Conversions            125 - 55
# 23                 4th Down Conversions: Conversion %              61.54%
# 24      4th Down Conversions:  Attempts - Conversions              13 - 8
# 25                               Red Zone:  Success %              80.65%
# 26                       Red Zone:  Attempts - Scores             31 - 25
# 27                            Field Goals:  Success %                 80%
# 28                      Field Goals:  Attempts - Made             15 - 12
# 29                            PAT Kicking:  Success %               96.2%
# 30                      PAT Kicking:  Attempts - Made             26 - 25
# 31                    2-Point Conversions:  Success %                   -
# 32              2-Point Conversions:  Attempts - Made               0 - 0
#
#              Opponents
# 0                 34.9
# 1              8 - 279
# 2                  188
# 3        66 - 111 - 11
# 4                 4.82
# 5      265 - 1277 - 15
# 6               158.08
# 7                 2618
# 8   297 - 193 - 8 - 22
# 9                 6.93
# 10          562 - 3895
# 11                5.10
# 12         10 - 51 - 0
# 13               21.46
# 14        13 - 279 - 0
# 15               46.28
# 16           25 - 1157
# 17         9 - 107 - 0
# 18              13 - 6
# 19            43 - 442
# 20            28:35.63
# 21              49.51%
# 22            103 - 51
# 23              45.45%
# 24              11 - 5
# 25              83.33%
# 26             30 - 25
# 27                 70%
# 28              10 - 7
# 29               97.3%
# 30             37 - 36
# 31                   -
# 32               0 - 0

# %%
df_col = df_col.drop(columns=['Opponents']).T
header = df_col.iloc[0]
df_col = df_col[1:]
df_col = df_col.rename(columns = header)
df_col
# Out:
#          Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# Colorado                  27.1                  8 - 217                 175
#
#          First Downs:  Rushing - Passing - By Penalty  \
# Colorado                                 73 - 90 - 12
#
#          Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Colorado                      4.31                 296 - 1277 - 11
#
#          Passing:  Rating Passing:  Yards  \
# Colorado           133.69            2097
#
#          Passing:  Attempts - Completions - Interceptions - TD  \
# Colorado                                 289 - 182 - 9 - 14
#
#          Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# Colorado                         5.77  ...                             61.54%
#
#          4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# Colorado                                        13 - 8               80.65%
#
#          Red Zone:  Attempts - Scores Field Goals:  Success %  \
# Colorado                      31 - 25                     80%
#
#          Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# Colorado                       15 - 12                   96.2%
#
#          PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# Colorado                       26 - 25                               -
#
#          2-Point Conversions:  Attempts - Made
# Colorado                                 0 - 0
#
# [1 rows x 33 columns]

# %% [markdown]
# **Arizona State Sun Devils**

# %%
url='http://www.cfbstats.com/2019/team/28/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Arizona State"
# 3:"Opponents"

# %%
dict_azst={title:column for (title,column) in col}
df_azst=pd.DataFrame(dict_azst)
df_azst
# Out:
#                                                             Arizona State  \
# 0                               Scoring:  Points/Game                23.4
# 1                            Scoring:  Games - Points             8 - 187
# 2                                 First Downs:  Total                 138
# 3        First Downs:  Rushing - Passing - By Penalty         53 - 77 - 8
# 4                           Rushing:  Yards / Attempt                3.69
# 5                     Rushing:  Attempts - Yards - TD     280 - 1033 - 10
# 6                                    Passing:  Rating              146.67
# 7                                     Passing:  Yards                1902
# 8   Passing:  Attempts - Completions - Interceptio...  223 - 135 - 2 - 11
# 9                        Total Offense:  Yards / Play                5.83
# 10                      Total Offense:  Plays - Yards          503 - 2935
# 11                      Punt Returns:  Yards / Return                9.58
# 12                Punt Returns:  Returns - Yards - TD        12 - 115 - 0
# 13                   Kickoff Returns:  Yards / Return               23.42
# 14             Kickoff Returns:  Returns - Yards - TD        12 - 281 - 0
# 15                             Punting:  Yards / Punt               46.84
# 16                            Punting:  Punts - Yards           38 - 1780
# 17               Interceptions:  Returns - Yards - TD          3 - 21 - 0
# 18                            Fumbles:  Number - Lost               8 - 5
# 19                         Penalties:  Number - Yards            51 - 523
# 20                          Time of Possession / Game            28:14.88
# 21                 3rd Down Conversions: Conversion %              40.18%
# 22      3rd Down Conversions:  Attempts - Conversions            112 - 45
# 23                 4th Down Conversions: Conversion %                 50%
# 24      4th Down Conversions:  Attempts - Conversions              10 - 5
# 25                               Red Zone:  Success %                 92%
# 26                       Red Zone:  Attempts - Scores             25 - 23
# 27                            Field Goals:  Success %               76.5%
# 28                      Field Goals:  Attempts - Made             17 - 13
# 29                            PAT Kicking:  Success %                100%
# 30                      PAT Kicking:  Attempts - Made             20 - 20
# 31                    2-Point Conversions:  Success %                100%
# 32              2-Point Conversions:  Attempts - Made               1 - 1
#
#              Opponents
# 0                 21.1
# 1              8 - 169
# 2                  159
# 3         54 - 89 - 16
# 4                 3.22
# 5       285 - 918 - 11
# 6               132.13
# 7                 1944
# 8   282 - 179 - 3 - 11
# 9                 5.05
# 10          567 - 2862
# 11                8.08
# 12         12 - 97 - 0
# 13               20.76
# 14        25 - 519 - 0
# 15               42.90
# 16           39 - 1673
# 17           2 - 7 - 0
# 18             20 - 11
# 19            49 - 392
# 20            31:45.13
# 21               43.9%
# 22            123 - 54
# 23              56.25%
# 24              16 - 9
# 25              83.33%
# 26             24 - 20
# 27               62.5%
# 28               8 - 5
# 29                100%
# 30             22 - 22
# 31                   -
# 32               0 - 0

# %%
df_azst = df_azst.drop(columns=['Opponents']).T
header = df_azst.iloc[0]
df_azst = df_azst[1:]
df_azst = df_azst.rename(columns = header)
df_azst
# Out:
#               Scoring:  Points/Game Scoring:  Games - Points  \
# Arizona State                  23.4                  8 - 187
#
#               First Downs:  Total  \
# Arizona State                 138
#
#               First Downs:  Rushing - Passing - By Penalty  \
# Arizona State                                  53 - 77 - 8
#
#               Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Arizona State                      3.69                 280 - 1033 - 10
#
#               Passing:  Rating Passing:  Yards  \
# Arizona State           146.67            1902
#
#               Passing:  Attempts - Completions - Interceptions - TD  \
# Arizona State                                 223 - 135 - 2 - 11
#
#               Total Offense:  Yards / Play  ...  \
# Arizona State                         5.83  ...
#
#               4th Down Conversions: Conversion %  \
# Arizona State                                50%
#
#               4th Down Conversions:  Attempts - Conversions  \
# Arizona State                                        10 - 5
#
#               Red Zone:  Success % Red Zone:  Attempts - Scores  \
# Arizona State                  92%                      25 - 23
#
#               Field Goals:  Success % Field Goals:  Attempts - Made  \
# Arizona State                   76.5%                       17 - 13
#
#               PAT Kicking:  Success % PAT Kicking:  Attempts - Made  \
# Arizona State                    100%                       20 - 20
#
#               2-Point Conversions:  Success %  \
# Arizona State                            100%
#
#               2-Point Conversions:  Attempts - Made
# Arizona State                                 1 - 1
#
# [1 rows x 33 columns]

# %% [markdown]
# **Stanford Cardinal**

# %%
url='http://www.cfbstats.com/2019/team/674/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"Stanford"
# 3:"Opponents"

# %%
dict_stan={title:column for (title,column) in col}
df_stan=pd.DataFrame(dict_stan)
df_stan
# Out:
#                                                                  Stanford  \
# 0                               Scoring:  Points/Game                22.6
# 1                            Scoring:  Games - Points             8 - 181
# 2                                 First Downs:  Total                 157
# 3        First Downs:  Rushing - Passing - By Penalty        51 - 88 - 18
# 4                           Rushing:  Yards / Attempt                3.68
# 5                     Rushing:  Attempts - Yards - TD       259 - 954 - 6
# 6                                    Passing:  Rating              125.57
# 7                                     Passing:  Yards                1834
# 8   Passing:  Attempts - Completions - Interceptio...  283 - 171 - 3 - 11
# 9                        Total Offense:  Yards / Play                5.14
# 10                      Total Offense:  Plays - Yards          542 - 2788
# 11                      Punt Returns:  Yards / Return                7.83
# 12                Punt Returns:  Returns - Yards - TD         12 - 94 - 1
# 13                   Kickoff Returns:  Yards / Return               26.81
# 14             Kickoff Returns:  Returns - Yards - TD        21 - 563 - 0
# 15                             Punting:  Yards / Punt               40.90
# 16                            Punting:  Punts - Yards           39 - 1595
# 17               Interceptions:  Returns - Yards - TD           6 - 4 - 0
# 18                            Fumbles:  Number - Lost               5 - 3
# 19                         Penalties:  Number - Yards            48 - 373
# 20                          Time of Possession / Game            34:05.25
# 21                 3rd Down Conversions: Conversion %              39.83%
# 22      3rd Down Conversions:  Attempts - Conversions            118 - 47
# 23                 4th Down Conversions: Conversion %                 30%
# 24      4th Down Conversions:  Attempts - Conversions              10 - 3
# 25                               Red Zone:  Success %              92.31%
# 26                       Red Zone:  Attempts - Scores             26 - 24
# 27                            Field Goals:  Success %               77.8%
# 28                      Field Goals:  Attempts - Made             18 - 14
# 29                            PAT Kicking:  Success %                100%
# 30                      PAT Kicking:  Attempts - Made             19 - 19
# 31                    2-Point Conversions:  Success %                  0%
# 32              2-Point Conversions:  Attempts - Made               1 - 0
#
#              Opponents
# 0                 28.0
# 1              8 - 224
# 2                  171
# 3          65 - 97 - 9
# 4                 4.46
# 5      270 - 1204 - 12
# 6               148.36
# 7                 2108
# 8   263 - 169 - 6 - 17
# 9                 6.21
# 10          533 - 3312
# 11                7.22
# 12          9 - 65 - 0
# 13               18.14
# 14        14 - 254 - 0
# 15               42.87
# 16           30 - 1286
# 17          3 - 43 - 0
# 18               7 - 4
# 19            49 - 446
# 20            25:54.75
# 21              44.66%
# 22            103 - 46
# 23                 50%
# 24              12 - 6
# 25              82.14%
# 26             28 - 23
# 27               63.6%
# 28              11 - 7
# 29                100%
# 30             29 - 29
# 31                   -
# 32               0 - 0

# %%
df_stan = df_stan.drop(columns=['Opponents']).T
header = df_stan.iloc[0]
df_stan = df_stan[1:]
df_stan = df_stan.rename(columns = header)
df_stan
# Out:
#          Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# Stanford                  22.6                  8 - 181                 157
#
#          First Downs:  Rushing - Passing - By Penalty  \
# Stanford                                 51 - 88 - 18
#
#          Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Stanford                      3.68                   259 - 954 - 6
#
#          Passing:  Rating Passing:  Yards  \
# Stanford           125.57            1834
#
#          Passing:  Attempts - Completions - Interceptions - TD  \
# Stanford                                 283 - 171 - 3 - 11
#
#          Total Offense:  Yards / Play  ... 4th Down Conversions: Conversion %  \
# Stanford                         5.14  ...                                30%
#
#          4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# Stanford                                        10 - 3               92.31%
#
#          Red Zone:  Attempts - Scores Field Goals:  Success %  \
# Stanford                      26 - 24                   77.8%
#
#          Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# Stanford                       18 - 14                    100%
#
#          PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# Stanford                       19 - 19                              0%
#
#          2-Point Conversions:  Attempts - Made
# Stanford                                 1 - 0
#
# [1 rows x 33 columns]

# %% [markdown]
# **California Golden Bears**

# %%
url='http://www.cfbstats.com/2019/team/107/index.html'#Create a handle, page, to handle the contents of the website
page = requests.get(url)#Store the contents of the website under doc
doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

tr_elements = doc.xpath('//tr')#Create empty list
col=[]
i=0#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
    
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
# Out:
# 1:""
# 2:"California"
# 3:"Opponents"

# %%
dict_cal={title:column for (title,column) in col}
df_cal=pd.DataFrame(dict_cal)
df_cal
# Out:
#                                                                California  \
# 0                               Scoring:  Points/Game                17.4
# 1                            Scoring:  Games - Points             8 - 139
# 2                                 First Downs:  Total                 136
# 3        First Downs:  Rushing - Passing - By Penalty        56 - 61 - 19
# 4                           Rushing:  Yards / Attempt                3.11
# 5                     Rushing:  Attempts - Yards - TD       301 - 935 - 6
# 6                                    Passing:  Rating              115.96
# 7                                     Passing:  Yards                1416
# 8   Passing:  Attempts - Completions - Interceptio...  219 - 114 - 6 - 10
# 9                        Total Offense:  Yards / Play                4.52
# 10                      Total Offense:  Plays - Yards          520 - 2351
# 11                      Punt Returns:  Yards / Return               12.63
# 12                Punt Returns:  Returns - Yards - TD         8 - 101 - 0
# 13                   Kickoff Returns:  Yards / Return               22.38
# 14             Kickoff Returns:  Returns - Yards - TD        13 - 291 - 0
# 15                             Punting:  Yards / Punt               39.34
# 16                            Punting:  Punts - Yards           47 - 1849
# 17               Interceptions:  Returns - Yards - TD          3 - 36 - 0
# 18                            Fumbles:  Number - Lost               9 - 3
# 19                         Penalties:  Number - Yards            40 - 337
# 20                          Time of Possession / Game            29:07.88
# 21                 3rd Down Conversions: Conversion %              33.91%
# 22      3rd Down Conversions:  Attempts - Conversions            115 - 39
# 23                 4th Down Conversions: Conversion %              33.33%
# 24      4th Down Conversions:  Attempts - Conversions              12 - 4
# 25                               Red Zone:  Success %              82.35%
# 26                       Red Zone:  Attempts - Scores             17 - 14
# 27                            Field Goals:  Success %               69.2%
# 28                      Field Goals:  Attempts - Made              13 - 9
# 29                            PAT Kicking:  Success %                100%
# 30                      PAT Kicking:  Attempts - Made             16 - 16
# 31                    2-Point Conversions:  Success %                   -
# 32              2-Point Conversions:  Attempts - Made               0 - 0
#
#             Opponents
# 0                20.8
# 1             8 - 166
# 2                 168
# 3         75 - 84 - 9
# 4                3.98
# 5     323 - 1286 - 12
# 6              117.16
# 7                1703
# 8   269 - 155 - 3 - 7
# 9                5.05
# 10         592 - 2989
# 11               8.39
# 12       18 - 151 - 0
# 13              25.85
# 14       13 - 336 - 0
# 15              40.44
# 16          39 - 1577
# 17         6 - 66 - 0
# 18             16 - 6
# 19           57 - 548
# 20           30:51.38
# 21             38.58%
# 22           127 - 49
# 23             66.67%
# 24            18 - 12
# 25                80%
# 26            30 - 24
# 27              64.7%
# 28            17 - 11
# 29               100%
# 30            19 - 19
# 31                  -
# 32              0 - 0

# %%
df_cal = df_cal.drop(columns=['Opponents']).T
header = df_cal.iloc[0]
df_cal = df_cal[1:]
df_cal = df_cal.rename(columns = header)
df_cal
# Out:
#            Scoring:  Points/Game Scoring:  Games - Points First Downs:  Total  \
# California                  17.4                  8 - 139                 136
#
#            First Downs:  Rushing - Passing - By Penalty  \
# California                                 56 - 61 - 19
#
#            Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# California                      3.11                   301 - 935 - 6
#
#            Passing:  Rating Passing:  Yards  \
# California           115.96            1416
#
#            Passing:  Attempts - Completions - Interceptions - TD  \
# California                                 219 - 114 - 6 - 10
#
#            Total Offense:  Yards / Play  ...  \
# California                         4.52  ...
#
#            4th Down Conversions: Conversion %  \
# California                             33.33%
#
#            4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# California                                        12 - 4               82.35%
#
#            Red Zone:  Attempts - Scores Field Goals:  Success %  \
# California                      17 - 14                   69.2%
#
#            Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# California                        13 - 9                    100%
#
#            PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# California                       16 - 16                               -
#
#            2-Point Conversions:  Attempts - Made
# California                                 0 - 0
#
# [1 rows x 33 columns]

# %% [markdown]
# # Combining the Team Stats DataFrames

# %% [markdown]
# Now that we have DataFrames for each team, we need to combine them into a single DataFrame.

# %%
df_teams = pd.concat([df_arz, df_azst, df_cal, df_col, df_ore, df_orst, df_stan, df_ucla, df_usc, df_utah, df_wash, df_wash_st])

# %%
df_teams
# Out:
#                  Scoring:  Points/Game Scoring:  Games - Points  \
# Arizona                           32.3                  8 - 258
# Arizona State                     23.4                  8 - 187
# California                        17.4                  8 - 139
# Colorado                          27.1                  8 - 217
# Oregon                            36.0                  8 - 288
# Oregon State                      30.4                  7 - 213
# Stanford                          22.6                  8 - 181
# UCLA                              29.1                  8 - 233
# USC                               31.3                  8 - 250
# Utah                              33.1                  8 - 265
# Washington                        35.8                  8 - 286
# Washington State                  41.8                  8 - 334
#
#                  First Downs:  Total  \
# Arizona                          189
# Arizona State                    138
# California                       136
# Colorado                         175
# Oregon                           193
# Oregon State                     160
# Stanford                         157
# UCLA                             176
# USC                              175
# Utah                             185
# Washington                       168
# Washington State                 202
#
#                  First Downs:  Rushing - Passing - By Penalty  \
# Arizona                                          82 - 101 - 6
# Arizona State                                     53 - 77 - 8
# California                                       56 - 61 - 19
# Colorado                                         73 - 90 - 12
# Oregon                                          72 - 107 - 14
# Oregon State                                      69 - 82 - 9
# Stanford                                         51 - 88 - 18
# UCLA                                             77 - 83 - 16
# USC                                              64 - 102 - 9
# Utah                                             92 - 75 - 18
# Washington                                       75 - 83 - 10
# Washington State                                36 - 154 - 12
#
#                  Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Arizona                               5.24                 309 - 1620 - 15
# Arizona State                         3.69                 280 - 1033 - 10
# California                            3.11                   301 - 935 - 6
# Colorado                              4.31                 296 - 1277 - 11
# Oregon                                5.05                 301 - 1521 - 14
# Oregon State                          4.88                 240 - 1170 - 12
# Stanford                              3.68                   259 - 954 - 6
# UCLA                                  4.02                 333 - 1337 - 13
# USC                                   4.48                 261 - 1170 - 13
# Utah                                  5.07                 346 - 1755 - 21
# Washington                            4.66                 295 - 1376 - 15
# Washington State                      5.10                   134 - 684 - 8
#
#                  Passing:  Rating Passing:  Yards  \
# Arizona                    147.45            2316
# Arizona State              146.67            1902
# California                 115.96            1416
# Colorado                   133.69            2097
# Oregon                     162.43            2207
# Oregon State               138.28            1706
# Stanford                   125.57            1834
# UCLA                       134.34            1895
# USC                        155.46            2369
# Utah                       175.61            1864
# Washington                 158.39            2000
# Washington State           162.07            3491
#
#                  Passing:  Attempts - Completions - Interceptions - TD  \
# Arizona                                          285 - 181 - 9 - 19
# Arizona State                                    223 - 135 - 2 - 11
# California                                       219 - 114 - 6 - 10
# Colorado                                         289 - 182 - 9 - 14
# Oregon                                           276 - 189 - 1 - 23
# Oregon State                                     250 - 147 - 2 - 18
# Stanford                                         283 - 171 - 3 - 11
# UCLA                                             265 - 158 - 7 - 16
# USC                                             282 - 200 - 10 - 18
# Utah                                             185 - 134 - 1 - 11
# Washington                                       236 - 159 - 3 - 16
# Washington State                                 418 - 290 - 9 - 34
#
#                  Total Offense:  Yards / Play  ...  \
# Arizona                                  6.63  ...
# Arizona State                            5.83  ...
# California                               4.52  ...
# Colorado                                 5.77  ...
# Oregon                                   6.46  ...
# Oregon State                             5.87  ...
# Stanford                                 5.14  ...
# UCLA                                     5.40  ...
# USC                                      6.52  ...
# Utah                                     6.82  ...
# Washington                               6.36  ...
# Washington State                         7.56  ...
#
#                  4th Down Conversions: Conversion %  \
# Arizona                                      81.82%
# Arizona State                                   50%
# California                                   33.33%
# Colorado                                     61.54%
# Oregon                                          50%
# Oregon State                                 71.43%
# Stanford                                        30%
# UCLA                                         42.86%
# USC                                          66.67%
# Utah                                         64.29%
# Washington                                    62.5%
# Washington State                             72.73%
#
#                  4th Down Conversions:  Attempts - Conversions  \
# Arizona                                                 11 - 9
# Arizona State                                           10 - 5
# California                                              12 - 4
# Colorado                                                13 - 8
# Oregon                                                  18 - 9
# Oregon State                                           14 - 10
# Stanford                                                10 - 3
# UCLA                                                    21 - 9
# USC                                                      6 - 4
# Utah                                                    14 - 9
# Washington                                             16 - 10
# Washington State                                        11 - 8
#
#                  Red Zone:  Success % Red Zone:  Attempts - Scores  \
# Arizona                           88%                      25 - 22
# Arizona State                     92%                      25 - 23
# California                     82.35%                      17 - 14
# Colorado                       80.65%                      31 - 25
# Oregon                         80.49%                      41 - 33
# Oregon State                   88.46%                      26 - 23
# Stanford                       92.31%                      26 - 24
# UCLA                           81.82%                      33 - 27
# USC                            77.42%                      31 - 24
# Utah                           80.56%                      36 - 29
# Washington                     91.43%                      35 - 32
# Washington State               92.68%                      41 - 38
#
#                  Field Goals:  Success % Field Goals:  Attempts - Made  \
# Arizona                              60%                        10 - 6
# Arizona State                      76.5%                       17 - 13
# California                         69.2%                        13 - 9
# Colorado                             80%                       15 - 12
# Oregon                             62.5%                         8 - 5
# Oregon State                       28.6%                         7 - 2
# Stanford                           77.8%                       18 - 14
# UCLA                               62.5%                         8 - 5
# USC                                88.9%                         9 - 8
# Utah                               63.6%                        11 - 7
# Washington                          100%                       15 - 15
# Washington State                    100%                       13 - 13
#
#                  PAT Kicking:  Success % PAT Kicking:  Attempts - Made  \
# Arizona                              97%                       33 - 32
# Arizona State                       100%                       20 - 20
# California                          100%                       16 - 16
# Colorado                           96.2%                       26 - 25
# Oregon                             97.4%                       38 - 37
# Oregon State                       96.4%                       28 - 27
# Stanford                            100%                       19 - 19
# UCLA                                100%                       30 - 30
# USC                                 100%                       32 - 32
# Utah                               97.1%                       35 - 34
# Washington                          100%                       33 - 33
# Washington State                    100%                       41 - 41
#
#                  2-Point Conversions:  Success %  \
# Arizona                                     100%
# Arizona State                               100%
# California                                     -
# Colorado                                       -
# Oregon                                      100%
# Oregon State                                  0%
# Stanford                                      0%
# UCLA                                        100%
# USC                                            -
# Utah                                           -
# Washington                                  100%
# Washington State                            100%
#
#                  2-Point Conversions:  Attempts - Made
# Arizona                                          1 - 1
# Arizona State                                    1 - 1
# California                                       0 - 0
# Colorado                                         0 - 0
# Oregon                                           1 - 1
# Oregon State                                     2 - 0
# Stanford                                         1 - 0
# UCLA                                             1 - 1
# USC                                              0 - 0
# Utah                                             0 - 0
# Washington                                       1 - 1
# Washington State                                 1 - 1
#
# [12 rows x 33 columns]

# %% [markdown]
# We now just have a single DataFrame with all of the PAC-12 teams.  There is an issue, however.  When our data was scraped, the team names were imported as index values instead of column values.  We will need to correct for this in order to perform a join later on with our conference statistics (df_conf) DataFrame.  The easiest way to do this is to just add a new column with the individual team names.  We will label this column "Name" so that it matches up with the column name in the df_conf DataFrame.

# %%
df_teams = df_teams.assign(Name = ["Arizona", "Arizona State", "California", "Colorado", "Oregon", "Oregon State", "Stanford", "UCLA", "USC", "Utah", "Washington", "Washington State"])
df_teams
# Out:
#                  Scoring:  Points/Game Scoring:  Games - Points  \
# Arizona                           32.3                  8 - 258
# Arizona State                     23.4                  8 - 187
# California                        17.4                  8 - 139
# Colorado                          27.1                  8 - 217
# Oregon                            36.0                  8 - 288
# Oregon State                      30.4                  7 - 213
# Stanford                          22.6                  8 - 181
# UCLA                              29.1                  8 - 233
# USC                               31.3                  8 - 250
# Utah                              33.1                  8 - 265
# Washington                        35.8                  8 - 286
# Washington State                  41.8                  8 - 334
#
#                  First Downs:  Total  \
# Arizona                          189
# Arizona State                    138
# California                       136
# Colorado                         175
# Oregon                           193
# Oregon State                     160
# Stanford                         157
# UCLA                             176
# USC                              175
# Utah                             185
# Washington                       168
# Washington State                 202
#
#                  First Downs:  Rushing - Passing - By Penalty  \
# Arizona                                          82 - 101 - 6
# Arizona State                                     53 - 77 - 8
# California                                       56 - 61 - 19
# Colorado                                         73 - 90 - 12
# Oregon                                          72 - 107 - 14
# Oregon State                                      69 - 82 - 9
# Stanford                                         51 - 88 - 18
# UCLA                                             77 - 83 - 16
# USC                                              64 - 102 - 9
# Utah                                             92 - 75 - 18
# Washington                                       75 - 83 - 10
# Washington State                                36 - 154 - 12
#
#                  Rushing:  Yards / Attempt Rushing:  Attempts - Yards - TD  \
# Arizona                               5.24                 309 - 1620 - 15
# Arizona State                         3.69                 280 - 1033 - 10
# California                            3.11                   301 - 935 - 6
# Colorado                              4.31                 296 - 1277 - 11
# Oregon                                5.05                 301 - 1521 - 14
# Oregon State                          4.88                 240 - 1170 - 12
# Stanford                              3.68                   259 - 954 - 6
# UCLA                                  4.02                 333 - 1337 - 13
# USC                                   4.48                 261 - 1170 - 13
# Utah                                  5.07                 346 - 1755 - 21
# Washington                            4.66                 295 - 1376 - 15
# Washington State                      5.10                   134 - 684 - 8
#
#                  Passing:  Rating Passing:  Yards  \
# Arizona                    147.45            2316
# Arizona State              146.67            1902
# California                 115.96            1416
# Colorado                   133.69            2097
# Oregon                     162.43            2207
# Oregon State               138.28            1706
# Stanford                   125.57            1834
# UCLA                       134.34            1895
# USC                        155.46            2369
# Utah                       175.61            1864
# Washington                 158.39            2000
# Washington State           162.07            3491
#
#                  Passing:  Attempts - Completions - Interceptions - TD  \
# Arizona                                          285 - 181 - 9 - 19
# Arizona State                                    223 - 135 - 2 - 11
# California                                       219 - 114 - 6 - 10
# Colorado                                         289 - 182 - 9 - 14
# Oregon                                           276 - 189 - 1 - 23
# Oregon State                                     250 - 147 - 2 - 18
# Stanford                                         283 - 171 - 3 - 11
# UCLA                                             265 - 158 - 7 - 16
# USC                                             282 - 200 - 10 - 18
# Utah                                             185 - 134 - 1 - 11
# Washington                                       236 - 159 - 3 - 16
# Washington State                                 418 - 290 - 9 - 34
#
#                  Total Offense:  Yards / Play  ...  \
# Arizona                                  6.63  ...
# Arizona State                            5.83  ...
# California                               4.52  ...
# Colorado                                 5.77  ...
# Oregon                                   6.46  ...
# Oregon State                             5.87  ...
# Stanford                                 5.14  ...
# UCLA                                     5.40  ...
# USC                                      6.52  ...
# Utah                                     6.82  ...
# Washington                               6.36  ...
# Washington State                         7.56  ...
#
#                  4th Down Conversions:  Attempts - Conversions  \
# Arizona                                                 11 - 9
# Arizona State                                           10 - 5
# California                                              12 - 4
# Colorado                                                13 - 8
# Oregon                                                  18 - 9
# Oregon State                                           14 - 10
# Stanford                                                10 - 3
# UCLA                                                    21 - 9
# USC                                                      6 - 4
# Utah                                                    14 - 9
# Washington                                             16 - 10
# Washington State                                        11 - 8
#
#                  Red Zone:  Success % Red Zone:  Attempts - Scores  \
# Arizona                           88%                      25 - 22
# Arizona State                     92%                      25 - 23
# California                     82.35%                      17 - 14
# Colorado                       80.65%                      31 - 25
# Oregon                         80.49%                      41 - 33
# Oregon State                   88.46%                      26 - 23
# Stanford                       92.31%                      26 - 24
# UCLA                           81.82%                      33 - 27
# USC                            77.42%                      31 - 24
# Utah                           80.56%                      36 - 29
# Washington                     91.43%                      35 - 32
# Washington State               92.68%                      41 - 38
#
#                  Field Goals:  Success % Field Goals:  Attempts - Made  \
# Arizona                              60%                        10 - 6
# Arizona State                      76.5%                       17 - 13
# California                         69.2%                        13 - 9
# Colorado                             80%                       15 - 12
# Oregon                             62.5%                         8 - 5
# Oregon State                       28.6%                         7 - 2
# Stanford                           77.8%                       18 - 14
# UCLA                               62.5%                         8 - 5
# USC                                88.9%                         9 - 8
# Utah                               63.6%                        11 - 7
# Washington                          100%                       15 - 15
# Washington State                    100%                       13 - 13
#
#                  PAT Kicking:  Success % PAT Kicking:  Attempts - Made  \
# Arizona                              97%                       33 - 32
# Arizona State                       100%                       20 - 20
# California                          100%                       16 - 16
# Colorado                           96.2%                       26 - 25
# Oregon                             97.4%                       38 - 37
# Oregon State                       96.4%                       28 - 27
# Stanford                            100%                       19 - 19
# UCLA                                100%                       30 - 30
# USC                                 100%                       32 - 32
# Utah                               97.1%                       35 - 34
# Washington                          100%                       33 - 33
# Washington State                    100%                       41 - 41
#
#                  2-Point Conversions:  Success %  \
# Arizona                                     100%
# Arizona State                               100%
# California                                     -
# Colorado                                       -
# Oregon                                      100%
# Oregon State                                  0%
# Stanford                                      0%
# UCLA                                        100%
# USC                                            -
# Utah                                           -
# Washington                                  100%
# Washington State                            100%
#
#                  2-Point Conversions:  Attempts - Made              Name
# Arizona                                          1 - 1           Arizona
# Arizona State                                    1 - 1     Arizona State
# California                                       0 - 0        California
# Colorado                                         0 - 0          Colorado
# Oregon                                           1 - 1            Oregon
# Oregon State                                     2 - 0      Oregon State
# Stanford                                         1 - 0          Stanford
# UCLA                                             1 - 1              UCLA
# USC                                              0 - 0               USC
# Utah                                             0 - 0              Utah
# Washington                                       1 - 1        Washington
# Washington State                                 1 - 1  Washington State
#
# [12 rows x 34 columns]

# %% [markdown]
# The new "Name" column has been added to the end of our DataFrame.
#
# We now need to join the two DataFrames.  We will use an inner join.  Since both DataFrames only have a single duplicate column, the join will automatically use this column ("Name").

# %%
df_all = pd.merge(df_conf, df_teams, how='inner')
df_all
# Out:
#                 Name  G  TD  FG  1XP  2XP  Safety  Points Points/G  \
# 0   Washington State  8  42  13   41    1       0     334     41.8
# 1             Oregon  8  39   5   37    1       0     288     36.0
# 2         Washington  8  34  15   33    1       1     286     35.8
# 3               Utah  8  35   7   34    0       0     265     33.1
# 4            Arizona  8  34   6   32    1       1     258     32.3
# 5                USC  8  32   8   32    0       1     250     31.3
# 6       Oregon State  7  30   2   27    0       0     213     30.4
# 7               UCLA  8  31   5   30    1       0     233     29.1
# 8           Colorado  8  26  12   25    0       0     217     27.1
# 9      Arizona State  8  21  13   20    1       0     187     23.4
# 10          Stanford  8  20  14   19    0       0     181     22.6
# 11        California  8  16   9   16    0       0     139     17.4
#
#    Scoring:  Points/Game  ... 4th Down Conversions: Conversion %  \
# 0                   41.8  ...                             72.73%
# 1                   36.0  ...                                50%
# 2                   35.8  ...                              62.5%
# 3                   33.1  ...                             64.29%
# 4                   32.3  ...                             81.82%
# 5                   31.3  ...                             66.67%
# 6                   30.4  ...                             71.43%
# 7                   29.1  ...                             42.86%
# 8                   27.1  ...                             61.54%
# 9                   23.4  ...                                50%
# 10                  22.6  ...                                30%
# 11                  17.4  ...                             33.33%
#
#    4th Down Conversions:  Attempts - Conversions Red Zone:  Success %  \
# 0                                         11 - 8               92.68%
# 1                                         18 - 9               80.49%
# 2                                        16 - 10               91.43%
# 3                                         14 - 9               80.56%
# 4                                         11 - 9                  88%
# 5                                          6 - 4               77.42%
# 6                                        14 - 10               88.46%
# 7                                         21 - 9               81.82%
# 8                                         13 - 8               80.65%
# 9                                         10 - 5                  92%
# 10                                        10 - 3               92.31%
# 11                                        12 - 4               82.35%
#
#    Red Zone:  Attempts - Scores Field Goals:  Success %  \
# 0                       41 - 38                    100%
# 1                       41 - 33                   62.5%
# 2                       35 - 32                    100%
# 3                       36 - 29                   63.6%
# 4                       25 - 22                     60%
# 5                       31 - 24                   88.9%
# 6                       26 - 23                   28.6%
# 7                       33 - 27                   62.5%
# 8                       31 - 25                     80%
# 9                       25 - 23                   76.5%
# 10                      26 - 24                   77.8%
# 11                      17 - 14                   69.2%
#
#    Field Goals:  Attempts - Made PAT Kicking:  Success %  \
# 0                        13 - 13                    100%
# 1                          8 - 5                   97.4%
# 2                        15 - 15                    100%
# 3                         11 - 7                   97.1%
# 4                         10 - 6                     97%
# 5                          9 - 8                    100%
# 6                          7 - 2                   96.4%
# 7                          8 - 5                    100%
# 8                        15 - 12                   96.2%
# 9                        17 - 13                    100%
# 10                       18 - 14                    100%
# 11                        13 - 9                    100%
#
#    PAT Kicking:  Attempts - Made 2-Point Conversions:  Success %  \
# 0                        41 - 41                            100%
# 1                        38 - 37                            100%
# 2                        33 - 33                            100%
# 3                        35 - 34                               -
# 4                        33 - 32                            100%
# 5                        32 - 32                               -
# 6                        28 - 27                              0%
# 7                        30 - 30                            100%
# 8                        26 - 25                               -
# 9                        20 - 20                            100%
# 10                       19 - 19                              0%
# 11                       16 - 16                               -
#
#    2-Point Conversions:  Attempts - Made
# 0                                  1 - 1
# 1                                  1 - 1
# 2                                  1 - 1
# 3                                  0 - 0
# 4                                  1 - 1
# 5                                  0 - 0
# 6                                  2 - 0
# 7                                  1 - 1
# 8                                  0 - 0
# 9                                  1 - 1
# 10                                 1 - 0
# 11                                 0 - 0
#
# [12 rows x 42 columns]

# %% [markdown]
# Our exercise is now complete.  In summary, here are the data transform/clean-up steps we performed to get to this final DataFrame:
# * Two separate data scrapes
# * Dropped unnecessary columns
# * Performed a rows to columns transform
# * Created column header names
# * Added a new column
# * Merged two DataFrames
# * Performed an inner join

# %% [markdown]
# The above stats summary is for Week 10 in the Pac-12.
#
# For comparison sake, and to demonstrate the power of this kind of web scraping, I have included the scraping results for weeks 11 and 12.  To generate these, all I had to do was re-run the code.  The scraping took care of everything in just a matter of seconds.

# %%
from IPython.display import Image
img = 'week_11.png'
Image(url=img)
# Out:
# <img src="week_11.png"/>

# %%
img = 'week_12.png'
Image(url=img)
# Out:
# <img src="week_12.png"/>
